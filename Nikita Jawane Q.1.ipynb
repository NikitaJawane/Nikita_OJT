# %%
#Q.1 Data visualisation and statistical measure
import numpy as np
import sympy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("iris (1).csv")
data
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
#Histogram
sns.histplot(data['Petal.Width'],kde=True,bins=20, color='violet')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Petal.Width', ylabel='Count'>

# %%
sns.histplot(data['Petal.Length'],kde=True,bins=20, color='violet')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Petal.Length', ylabel='Count'>

# %%
sns.histplot(data['Sepal.Length'],kde=True,bins=20, color='b')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sepal.Length', ylabel='Count'>

# %%
sns.histplot(data['Sepal.Width'],kde=True,bins=20, color='b')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sepal.Width', ylabel='Count'>

# %%
plt.scatter(data['Sepal.Length'],data['Sepal.Width'],marker="*")

# %%
plt.scatter(data['Petal.Length'],data['Petal.Width'],color='orange',marker="*")

# %%
plt.scatter(data['Sepal.Length'],data['Sepal.Width'],data['Petal.Length'],data['Petal.Width'],marker='*')

# %%
sns.boxplot(x='Sepal.Width',data=data,color='orange')
# Out:
# <Axes: xlabel='Sepal.Width'>

# %%
sns.boxplot(x='Sepal.Length',data=data,color='orange')
# Out:
# <Axes: xlabel='Sepal.Length'>

# %%
sns.boxplot(x='Petal.Length',data=data,color='g')
# Out:
# <Axes: xlabel='Petal.Length'>

# %%
sns.boxplot(x='Petal.Width',data=data,color='g')
# Out:
# <Axes: xlabel='Petal.Width'>

# %%
#plot subplot 
plt.subplot(221)
plt.scatter(data['Petal.Length'],data['Petal.Width'],c='orange')
plt.subplot(222)
plt.scatter(data['Sepal.Length'],data['Sepal.Width'],c='red')
plt.subplot(223)
plt.scatter(data['Sepal.Length'],data['Petal.Width'],c='green')
plt.subplot(224)
plt.scatter(data['Petal.Length'],data['Sepal.Width'],c='violet')

# %%
median1= data['Sepal.Width'].median()
median1
# Out:
# 3.0

# %%
median2= data['Sepal.Length'].median()
median2
# Out:
# 5.8

# %%
median3= data['Petal.Width'].median()
median3
# Out:
# 1.3

# %%
median4= data['Petal.Length'].median()
median4
# Out:
# 4.35

# %%
mode1= data['Sepal.Width'].mode()
mode1
# Out:
# 0    3.0
# Name: Sepal.Width, dtype: float64

# %%
mode2= data['Sepal.Length'].mode()
mode2
# Out:
# 0    5.0
# Name: Sepal.Length, dtype: float64

# %%
mode3= data['Petal.Width'].mode()
mode3
# Out:
# 0    0.2
# Name: Petal.Width, dtype: float64

# %%
mode4= data['Petal.Length'].mode()
mode4
# Out:
# 0    1.4
# 1    1.5
# Name: Petal.Length, dtype: float64

# %%
data.describe()
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
